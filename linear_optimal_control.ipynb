# %% [markdown]
# # Linear Optimal Control
#
# This notebook contains code for solving for the analytical solutions for the bang-bang finite-horzon optimal controls in repairing the network as a function of different model parameter values. The figures are relevant in Figure 2bcd of the main text.

# %%
from linear_plots import *

# %% [markdown]
# ## Figure 2bcd: Analytic solutions to optimal repair protocol in linear, finite horizon
#
# NOTE: The following code uses data that was saved from a long run using the Harvard Odyssey2 supercomputing cluster. For more information on simulating the data on a SLURM-type computing cluster, refer to the miscellaneous code files.

# %%
plotHD_wCurve (['repair_f_flip', 'repair_r_flip', 'repair_a_flip'], 
        ['varyf_f0.098_r0.01_a0.1_T100_step1_d0_depoff_N1000',
         'newvaryr_f0.025_r0.0988_a10_T100_step1_d0_depoff_N1000',
         'varya_f0.025_r0.01_a0.196_T100_step1_d0_depoff_N1000'], 
        [['T1_T2',0,0.12,0.002,'$f$'],['T1_T2',0,0.1,0.0019,'$r$'],['T1_T2',0,20,0.4,r'$\alpha$']], curve_type='numeric',
        dpi=700, flip=True, fill=True)

plotHD_wCurve (['repair_f', 'repair_r', 'repair_a'], 
        ['varyf_f0.098_r0.01_a0.1_T100_step1_d0_depoff_N1000',
         'newvaryr_f0.025_r0.0988_a10_T100_step1_d0_depoff_N1000',
         'varya_f0.025_r0.01_a0.196_T100_step1_d0_depoff_N1000'], 
        [['T1_T2',0,0.1,0.002,'$f$'],['T1_T2',0,0.1,0.0019,'$r$'],['T1_T2',0,20,0.4,r'$\alpha$']], curve_type='numeric',
        dpi=700)
# Out:
# C:\Users\edsun\Anaconda3\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
